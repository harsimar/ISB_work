# %%
from matplotlib import pyplot as plt
import pandas
import numpy as np

chroms = ['Subject ID'] #represents a list of one person's chromosome data
col_names = ['Subject ID', 'ID', 'Gestalt ID', 'Vendor', 'Gender', 'File Type'] #represents names field for df
for i in range(1, 23):
    col_names.append('chr%s' % i) #appends chroms to names list
    chroms.append('chr%s' % i) #appends chroms to one person list
    
#adding on the extras
col_names.append('chrX') 
col_names.append('chrY')
col_names.append('chrM')
chroms.append('chrX')
chroms.append('chrY')
chroms.append('chrM')


chromosome_counts = pandas.read_table( 
    'file_counts_20160615.txt', #the file we are reading in
    skiprows=1,#skip the first row
    names= col_names)#names of the columns

#chromosome_counts = 
chromosome_counts.set_index("Subject ID", drop=False, inplace = True) #sets index to first col

# %%
chromosome_counts.head()
# Out:
#                 Subject ID                 ID         Gestalt ID Vendor  \
# Subject ID
# 102-01276-02  102-01276-02  LP6005754-DNA_H01  LP6005754-DNA_H01   ILMN
# 102-01276-02  102-01276-02  LP6005754-DNA_H01  LP6005754-DNA_H01   ILMN
# 102-01276-02  102-01276-02  LP6005754-DNA_H01  LP6005754-DNA_H01   ILMN
# 102-08019-01  102-08019-01  LP6005978-DNA_C06  LP6005978-DNA_C06   ILMN
# 102-08019-01  102-08019-01  LP6005978-DNA_C06  LP6005978-DNA_C06   ILMN
#
#               Gender File Type      chr1      chr2      chr3      chr4  ...   \
# Subject ID                                                              ...
# 102-01276-02    Male      GVCF  10571558  10480160   8388436   7858688  ...
# 102-01276-02    Male       RCF   1188058   1080103    824897    877191  ...
# 102-01276-02    Male       VCF   1188058   1080103    824897    877191  ...
# 102-08019-01  Female      GVCF  24695702  24340818  19277950  17368719  ...
# ...

# %%
gvcf_index = chromosome_counts.set_index("File Type", drop = False) #sets index to file col

# %%
gvcf_index.head() #prints out the table with file as the index
# Out:
#              Subject ID                 ID         Gestalt ID Vendor  Gender  \
# File Type
# GVCF       102-01276-02  LP6005754-DNA_H01  LP6005754-DNA_H01   ILMN    Male
# RCF        102-01276-02  LP6005754-DNA_H01  LP6005754-DNA_H01   ILMN    Male
# VCF        102-01276-02  LP6005754-DNA_H01  LP6005754-DNA_H01   ILMN    Male
# GVCF       102-08019-01  LP6005978-DNA_C06  LP6005978-DNA_C06   ILMN  Female
# RCF        102-08019-01  LP6005978-DNA_C06  LP6005978-DNA_C06   ILMN  Female
#
#           File Type      chr1      chr2      chr3      chr4  ...     chr16  \
# File Type                                                    ...
# GVCF           GVCF  10571558  10480160   8388436   7858688  ...   4178214
# RCF             RCF   1188058   1080103    824897    877191  ...    526398
# VCF             VCF   1188058   1080103    824897    877191  ...    526398
# GVCF           GVCF  24695702  24340818  19277950  17368719  ...   9967068
# ...

# %%
gvcfs = gvcf_index.loc["GVCF"] #returns rows labelled by "GVCF" (so gvcfs is a dataframe)

# %%
gvcfs #this is what gvcfs looks like
# Out:
#              Subject ID                 ID         Gestalt ID Vendor  Gender  \
# File Type
# GVCF       102-01276-02  LP6005754-DNA_H01  LP6005754-DNA_H01   ILMN    Male
# GVCF       102-08019-01  LP6005978-DNA_C06  LP6005978-DNA_C06   ILMN  Female
# GVCF          F-101-608    GS000019584-DID    GS000015669-ASM     CG    Male
# GVCF       102-01190-03  LP6005983-DNA_A05  LP6005983-DNA_A05   ILMN  Female
# GVCF         NB-101-645    GS000023633-DID    GS000019335-ASM     CG  Female
# GVCF       102-08017-03  LP6005978-DNA_G05  LP6005978-DNA_G05   ILMN  Female
# GVCF         NB-101-466    GS000016829-DID    GS000014523-ASM     CG    Male
# GVCF       102-00106-03  LP6005637-DNA_D07  LP6005637-DNA_D07   ILMN    Male
# GVCF       102-07062-01  LP6008045-DNA_D05  LP6008045-DNA_D05   ILMN  Female
# GVCF          F-101-680    GS000020340-DID    GS000016513-ASM     CG    Male
# GVCF       102-00743-02  LP6005701-DNA_B08  LP6005701-DNA_B08   ILMN    Male
# ...

# %%
gvcf_chroms = gvcfs[chroms].set_index('Subject ID') #returns a new dataframe of just gvcf chromosome data that has the index set to 'Subject ID'

# %%
gvcf_chroms.iloc[0] #isolates the first row with col labels
# Out:
# chr1     10571558
# chr2     10480160
# chr3      8388436
# chr4      7858688
# chr5      7568742
# chr6      7291406
# chr7      7092297
# chr8      6234254
# chr9      5497591
# chr10     6067887
# chr11     6015911
# chr12     5937391
# chr13     4017611
# chr14     4045792
# chr15     3874058
# chr16     4178214
# chr17     4295057
# chr18     3240728
# chr19     3492104
# chr20     2973279
# chr21     1726669
# chr22     2053683
# chrX      8189324
# chrY       998266
# chrM         9399
# Name: 102-01276-02, dtype: int64

# %%
current = gvcf_chroms.loc['102-01276-02'] #locating first row by Subject ID number (which is what the index has been set to)

# %%
plt.xlabel('Chromosome #') # x axis label
plt.ylabel('Variant Counts of chromosomes') # y axis label 
plt.title('Bar graph of counts for Subject ID 102-01276-02') #title

y = current.dropna()
x = range(len(y))
width = 1/1.5

chrom_Labels = chroms[1:]
x_location = np.arange(0.5, 25.5, 1)
plt.bar(x, y , width, color = "blue")  
plt.xticks(x_location, chrom_Labels)

plt.show()

# %%
chrom_Labels
# Out:
# ['chr1',
#  'chr2',
#  'chr3',
#  'chr4',
#  'chr5',
#  'chr6',
#  'chr7',
#  'chr8',
#  'chr9',
#  'chr10',
#  'chr11',
#  'chr12',
#  'chr13',
#  'chr14',
#  'chr15',
#  'chr16',
#  'chr17',
#  'chr18',
#  'chr19',
#  'chr20',
#  'chr21',
#  'chr22',
#  'chrX',
#  'chrY',
#  'chrM']

# %%
# Out:
# File Type
# GVCF    9399
# GVCF    8415
# GVCF      55
# GVCF    8084
# GVCF      47
# GVCF    9070
# GVCF     148
# GVCF    7336
# GVCF    8858
# GVCF      67
# GVCF    9573
# GVCF    8354
# GVCF      91
# GVCF      45
# GVCF      96
# GVCF    8432
# GVCF      57
# GVCF    7123
# GVCF      48
# GVCF    8336
# GVCF      56
# GVCF    8851
# GVCF    8966
# GVCF    7947
# GVCF    7780
# GVCF      38
# GVCF    7606
# GVCF    8377
# GVCF      66
# GVCF    8106
#         ...
# GVCF    6874
# GVCF    7918
# GVCF    8298
# GVCF    7727
# GVCF    9483
# GVCF    8463
# GVCF    8489
# GVCF      80
# GVCF     117
# GVCF      79
# GVCF      87
# GVCF    8644
# GVCF      80
# GVCF      35
# GVCF    7712
# GVCF    7645
# GVCF     129
# GVCF    8607
# GVCF    8344
# GVCF    7672
# GVCF    8726
# GVCF    7648
# GVCF    7594
# GVCF    9032
# GVCF    7596
# GVCF    7654
# GVCF      58
# GVCF      53
# GVCF      60
# GVCF      74
# Name: chrM, dtype: int64
