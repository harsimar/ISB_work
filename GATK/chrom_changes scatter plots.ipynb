# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import pandas

#chrom changes file
col_names = ['Read ID', 'chromosome', 'Y Starting Base Position', 'Percent Match', 'Second Position', 'ChangeTo', 'Starting Base Position', 'Percent Match2', 'Second Position2']
chrom_changes = pandas.read_table( 
    'LP6005636-DNA_H02.chrom_changes.txt', #the file we are reading in
    names= col_names)#names of the columns
 
chrom_changes.set_index("Read ID", drop=True, inplace = True) #sets index to first col
chrom_changes.head()
# Out:
#                              chromosome  Y Starting Base Position  \
# Read ID
# C2D1RACXX_1:8:1101:1000601:0       chrY                  13484087
# C2D1RACXX_1:8:1101:1000601:0       chrY                  13484087
# C2D1RACXX_1:8:1101:1000739:0       chrY                  13664682
# C2D1RACXX_1:8:1101:1000739:0       chrY                  13664682
# C2D1RACXX_1:8:1101:1001197:0       chrY                  26046243
#
#                              Percent Match Second Position ChangeTo  \
# Read ID
# C2D1RACXX_1:8:1101:1000601:0          100M               =    chr18
# C2D1RACXX_1:8:1101:1000601:0          100M               =    chr18
# C2D1RACXX_1:8:1101:1000739:0      3S84M13S               =     chr4
# C2D1RACXX_1:8:1101:1000739:0      3S84M13S               =    chr21
# C2D1RACXX_1:8:1101:1001197:0          100M               =    chr10
#
#                               Starting Base Position Percent Match2  \
# Read ID
# C2D1RACXX_1:8:1101:1000601:0                  108134      38S44M18S
# C2D1RACXX_1:8:1101:1000601:0                  107998        5S91M4S
# C2D1RACXX_1:8:1101:1000739:0                49105559       48M5D52M
# C2D1RACXX_1:8:1101:1000739:0                10776646         56M44S
# C2D1RACXX_1:8:1101:1001197:0                59885544      61S25M14S
#
#                              Second Position2
# Read ID
# C2D1RACXX_1:8:1101:1000601:0                =
# C2D1RACXX_1:8:1101:1000601:0                =
# C2D1RACXX_1:8:1101:1000739:0            chr21
# C2D1RACXX_1:8:1101:1000739:0             chr4
# C2D1RACXX_1:8:1101:1001197:0                =

# %%
#Creating a list of chroms for iteration, and a dictionary of chrom --> chrom length to configure the axes of the graph
chroms = ['chr%s' % i for i in range(1, 23) + ['X', 'M']]

# lengths of chromosomes taken from https://genome.ucsc.edu/goldenpath/help/hg19.chrom.sizes
# lengths listed in order from 1-22, X, M, Y
chr_lengths = [249250621, 243199373,198022430,191154276, 180915260, 
               171115067, 159138663, 146364022, 141213431, 
               135534747, 135006516, 133851895, 115169878, 107349540, 
               102531392, 90354753, 81195210, 78077248, 59128983,
               63025520, 48129895, 51304566, 155270560, 16571, 59373566]  


chr_lengths_dict = {}
for i, chrom in enumerate(chroms):
    chr_lengths_dict[chrom] = chr_lengths[i] 
chr_lengths_dict['chrY'] = chr_lengths[len(chr_lengths) - 1]

# %%
#Scatterplots for chrY vs chr1 - chr10
#pp = PdfPages('chrom_changes scatter plots.pdf')
for chrom in chroms[0:10]:
    subset = chrom_changes.loc[chrom_changes['ChangeTo'] == chrom] 
    ax.set_title("Scatter Plot of chrY read vs %s read" %chrom)
    ax.set_ylabel('%s Starting BP Position of read' %chrom)
    ax.set_xlabel('chrY Starting BP Position of read')
    print(chrom)
    print(len(subset['Y Starting Base Position']))
    print(len(subset['Starting Base Position']))
    print(subset['Starting Base Position'].head())
    print(subset['Y Starting Base Position'].head())
    ax.scatter(subset['Y Starting Base Position'][0:100], subset['Starting Base Position'][0:100], s = 5)
    plt.axis([0, chr_lengths_dict['chrY'], 0, chr_lengths_dict[chrom]])
    #plt.savefig(pp, format='pdf')
    plt.show()
#pp.close()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# chr1
# 445196
# 445196
# Read ID
# C2D1RACXX_1:8:1101:1001256:0    119721809
# C2D1RACXX_1:8:1101:100254:0        126003
# C2D1RACXX_1:8:1101:100254:0        126258
# C2D1RACXX_1:8:1101:1003477:0    119720918
# C2D1RACXX_1:8:1101:1009740:0    142541236
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1001256:0    16000191
# C2D1RACXX_1:8:1101:100254:0     26432337
# C2D1RACXX_1:8:1101:100254:0     26432337
# C2D1RACXX_1:8:1101:1003477:0    25225021
# C2D1RACXX_1:8:1101:1009740:0    58979357
# Name: Y Starting Base Position, dtype: int64
# chr2
# 461781
# 461781
# Read ID
# C2D1RACXX_1:8:1101:1004727:0    172000034
# C2D1RACXX_1:8:1101:1006057:0     89860409
# C2D1RACXX_1:8:1101:1008044:0     96598291
# C2D1RACXX_1:8:1101:1008044:0     96598397
# C2D1RACXX_1:8:1101:1012259:0     89860431
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1004727:0    18647583
# C2D1RACXX_1:8:1101:1006057:0    13458393
# C2D1RACXX_1:8:1101:1008044:0    28579517
# C2D1RACXX_1:8:1101:1008044:0    28579517
# C2D1RACXX_1:8:1101:1012259:0    58827377
# Name: Y Starting Base Position, dtype: int64
# chr3
# 351933
# 351933
# Read ID
# C2D1RACXX_1:8:1101:1003329:0    150576479
# C2D1RACXX_1:8:1101:1003477:0     17859804
# C2D1RACXX_1:8:1101:1003594:0     87146608
# C2D1RACXX_1:8:1101:1003594:0     87146320
# C2D1RACXX_1:8:1101:1014760:0     90354527
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1003329:0    21246369
# C2D1RACXX_1:8:1101:1003477:0    25225021
# C2D1RACXX_1:8:1101:1003594:0    25903561
# C2D1RACXX_1:8:1101:1003594:0    25903561
# C2D1RACXX_1:8:1101:1014760:0    10090886
# Name: Y Starting Base Position, dtype: int64
# chr4
# 940917
# 940917
# Read ID
# C2D1RACXX_1:8:1101:1000739:0    49105559
# C2D1RACXX_1:8:1101:1002667:0    49101453
# C2D1RACXX_1:8:1101:1002667:0    49101777
# C2D1RACXX_1:8:1101:1005154:0    49158466
# C2D1RACXX_1:8:1101:1005370:0    49157449
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1000739:0    13664682
# C2D1RACXX_1:8:1101:1002667:0    58835017
# C2D1RACXX_1:8:1101:1002667:0    58835017
# C2D1RACXX_1:8:1101:1005154:0    58823270
# C2D1RACXX_1:8:1101:1005370:0    13458442
# Name: Y Starting Base Position, dtype: int64
# chr5
# 140021
# 140021
# Read ID
# C2D1RACXX_1:8:1101:1009498:0    41661015
# C2D1RACXX_1:8:1101:1009498:0    41661217
# C2D1RACXX_1:8:1101:1009757:0    42030111
# C2D1RACXX_1:8:1101:1011953:0    49537071
# C2D1RACXX_1:8:1101:101332:0     49534894
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1009498:0     6772262
# C2D1RACXX_1:8:1101:1009498:0     6772262
# C2D1RACXX_1:8:1101:1009757:0     9473522
# C2D1RACXX_1:8:1101:1011953:0    10057328
# C2D1RACXX_1:8:1101:101332:0     10082114
# Name: Y Starting Base Position, dtype: int64
# chr6
# 135962
# 135962
# Read ID
# C2D1RACXX_1:8:1101:1003329:0     22844395
# C2D1RACXX_1:8:1101:1003974:0     78849481
# C2D1RACXX_1:8:1101:101861:0     137489376
# C2D1RACXX_1:8:1101:101861:0     137489149
# C2D1RACXX_1:8:1101:1040682:0     87373790
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1003329:0    21246369
# C2D1RACXX_1:8:1101:1003974:0    23135789
# C2D1RACXX_1:8:1101:101861:0     21162804
# C2D1RACXX_1:8:1101:101861:0     21162804
# C2D1RACXX_1:8:1101:1040682:0    22318737
# Name: Y Starting Base Position, dtype: int64
# chr7
# 252706
# 252706
# Read ID
# C2D1RACXX_1:8:1101:1011741:0    45591115
# C2D1RACXX_1:8:1101:1011741:0    45590841
# C2D1RACXX_1:8:1101:1016798:0    61639038
# C2D1RACXX_1:8:1101:1025049:0    57994766
# C2D1RACXX_1:8:1101:1029288:0    66899514
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1011741:0    20039779
# C2D1RACXX_1:8:1101:1011741:0    20039779
# C2D1RACXX_1:8:1101:1016798:0     9919079
# C2D1RACXX_1:8:1101:1025049:0    10087775
# C2D1RACXX_1:8:1101:1029288:0    22562958
# Name: Y Starting Base Position, dtype: int64
# chr8
# 245553
# 245553
# Read ID
# C2D1RACXX_1:8:1101:1001219:0      8917681
# C2D1RACXX_1:8:1101:1002413:0     63702683
# C2D1RACXX_1:8:1101:1002413:0     63702492
# C2D1RACXX_1:8:1101:1003329:0    130917471
# C2D1RACXX_1:8:1101:100384:0      43224901
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1001219:0    21108970
# C2D1RACXX_1:8:1101:1002413:0     7575526
# C2D1RACXX_1:8:1101:1002413:0     7575526
# C2D1RACXX_1:8:1101:1003329:0    21246369
# C2D1RACXX_1:8:1101:100384:0     26189186
# Name: Y Starting Base Position, dtype: int64
# chr9
# 134037
# 134037
# Read ID
# C2D1RACXX_1:8:1101:1014760:0     69703649
# C2D1RACXX_1:8:1101:1017667:0     78790112
# C2D1RACXX_1:8:1101:1018146:0     66465493
# C2D1RACXX_1:8:1101:1018146:0     66465159
# C2D1RACXX_1:8:1101:101916:0     141084009
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1014760:0    10090886
# C2D1RACXX_1:8:1101:1017667:0    58842112
# C2D1RACXX_1:8:1101:1018146:0     9937811
# C2D1RACXX_1:8:1101:1018146:0     9937811
# C2D1RACXX_1:8:1101:101916:0      9975924
# Name: Y Starting Base Position, dtype: int64
# chr10
# 1348404
# 1348404
# Read ID
# C2D1RACXX_1:8:1101:1001197:0    59885544
# C2D1RACXX_1:8:1101:1001197:0    59885813
# C2D1RACXX_1:8:1101:1003873:0    39144405
# C2D1RACXX_1:8:1101:1003873:0    39144720
# C2D1RACXX_1:8:1101:1003974:0    43797188
# Name: Starting Base Position, dtype: int64
# Read ID
# C2D1RACXX_1:8:1101:1001197:0    26046243
# C2D1RACXX_1:8:1101:1001197:0    26046243
# C2D1RACXX_1:8:1101:1003873:0    13834870
# C2D1RACXX_1:8:1101:1003873:0    13834870
# C2D1RACXX_1:8:1101:1003974:0    23135789
# Name: Y Starting Base Position, dtype: int64

# %%
#Scatterplots for chrY vs chr11 - chrM
pp2 = PdfPages('chrom_changes scatter plots2.pdf')
for chrom in chroms[10:]:
    subset = chrom_changes.loc[chrom_changes['ChangeTo'] == chrom] #change the chr14 to whatever is in chrom list when looping through all chroms
    fig, ax = plt.subplots() 
    ax.set_title("Scatter Plot of chrY read vs %s read" %chrom)
    ax.set_ylabel('%s Starting BP Position of read' %chrom)
    ax.set_xlabel('chrY Starting BP Position of read')
    ax.scatter(subset['Y Starting Base Position'], subset['Starting Base Position'], s = 5)
    plt.axis([0, chr_lengths_dict['chrY'], 0, chr_lengths_dict[chrom]])
    plt.savefig(pp2, format='pdf')
pp2.close()

# %%
chrom_changes.groupby('ChangeTo').size()
